# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\chaud\Downloads\archive.zip",
               header=0,index_col=0)
df.head()
# Out:
#           Customer ID Platform Order Date & Time  Delivery Time (Minutes)  \
# Order ID
# ORD000001    CUST2824  JioMart           19:29.5                       30
# ORD000002    CUST1409  Blinkit           54:29.5                       16
# ORD000003    CUST5506  JioMart           21:29.5                       25
# ORD000004    CUST5012  JioMart           19:29.5                       42
# ORD000005    CUST4657  Blinkit           49:29.5                       30
#
#               Product Category  Order Value (INR)  \
# Order ID
# ORD000001  Fruits & Vegetables                382
# ORD000002                Dairy                279
# ORD000003            Beverages                599
# ORD000004            Beverages                946
# ORD000005            Beverages                334
#
#                        Customer Feedback  Service Rating Delivery Delay  \
# Order ID
# ORD000001  Fast delivery, great service!               5             No
# ...

# %%
zepto_valuation = 5_000_000_000  # USD
print(f"Zepto's current valuation is ${zepto_valuation:,}")
# Out:
# Zepto's current valuation is $5,000,000,000

# %%
valuation_history = {
    "2021": 60_000_000,
    "2022": 900_000_000,
    "2023": 1_400_000_000,
    "2024": 5_000_000_000
}
for year, value in valuation_history.items():
    print(f"{year}: ${value:,}")
# Out:
# 2021: $60,000,000
# 2022: $900,000,000
# 2023: $1,400,000,000
# 2024: $5,000,000,000

# %%
funding_rounds = [2_000_000, 60_000_000, 200_000_000, 500_000_000]
total_funding = sum(funding_rounds)
print(f"Total funding raised: ${total_funding:,}")
# Out:
# Total funding raised: $762,000,000

# %%
revenue = {
    "2022": 150_000_000,
    "2023": 400_000_000,
    "2024": 750_000_000
}
for year, amount in revenue.items():
    print(f"{year} revenue: ${amount:,}")
# Out:
# 2022 revenue: $150,000,000
# 2023 revenue: $400,000,000
# 2024 revenue: $750,000,000

# %%
unit_economics = {
    "average_order_value": 300,
    "delivery_cost": 50
}
for key, value in unit_economics.items():
    print(f"{key.replace('_', ' ').title()}: ₹{value}")
# Out:
# Average Order Value: ₹300
# Delivery Cost: ₹50

# %%
projected_ipo_valuation = 6_500_000_000  # Hypothetical
print(f"Projected IPO Valuation: ${projected_ipo_valuation:,}")
# Out:
# Projected IPO Valuation: $6,500,000,000

# %%
zepto_unit_economics = {
    "avg_order_value": 300,
    "delivery_cost": 50,
    "gross_margin": 0.25
}
print("Zepto Unit Economics:")
for k, v in zepto_unit_economics.items():
    print(f"{k}: {v}")
# Out:
# Zepto Unit Economics:
# avg_order_value: 300
# delivery_cost: 50
# gross_margin: 0.25

# %%
operating_margin = {
    "2022": -0.35,
    "2023": -0.20,
    "2024": -0.10
}
print("Operating Margin (%):")
for year, margin in operating_margin.items():
    print(f"{year}: {margin * 100:.1f}%")
# Out:
# Operating Margin (%):
# 2022: -35.0%
# 2023: -20.0%
# 2024: -10.0%

# %%
expenses = {
    "Logistics": 40,
    "Marketing": 30,
    "Technology": 20,
    "Admin": 10
}
for category, percent in expenses.items():
    print(f"{category}: {percent}% of total expenses")
# Out:
# Logistics: 40% of total expenses
# Marketing: 30% of total expenses
# Technology: 20% of total expenses
# Admin: 10% of total expenses

# %%
financial_risks = [
    "High burn rate",
    "Intense competition",
    "Thin margins",
    "Customer retention costs",
    "Regulatory uncertainty"
]
print("Key Financial Risks:")
for risk in financial_risks:
    print(f"- {risk}")
# Out:
# Key Financial Risks:
# - High burn rate
# - Intense competition
# - Thin margins
# - Customer retention costs
# - Regulatory uncertainty

# %%
ipo_valuation = 6_500_000_000(#initial public offering)
print(f"Expected IPO valuation: ${ipo_valuation:,}")
# Out:
# Expected IPO valuation: $6,500,000,000

# %%
# Question 10: How would Zepto's valuation change under different growth scenarios?
growth_scenarios = {
    "base_case": 6_500_000_000,
    "bull_case": 8_000_000_000,
    "bear_case": 5_000_000_000
}
print("Valuation Scenarios (USD):")
for case, value in growth_scenarios.items():
    print(f"{case}: ${value:,}")
# Out:
# Valuation Scenarios (USD):
# base_case: $6,500,000,000
# bull_case: $8,000,000,000
# bear_case: $5,000,000,000

# %%
total_cost = 800_000_000
target_profit_margin = 0.10

required_revenue = total_cost / (1 - target_profit_margin)
print(f"Breakeven revenue for 10% profit: ${required_revenue:,.0f}")
# Out:
# Breakeven revenue for 10% profit: $888,888,889

# %%
buy_price = 65
sell_price = 90

return_percent = ((sell_price - buy_price) / buy_price) * 100
print(f"Investor return: {return_percent:.2f}%")
# Out:
# Investor return: 38.46%
